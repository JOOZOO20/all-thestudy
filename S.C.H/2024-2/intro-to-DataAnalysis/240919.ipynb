# %%
import pandas as pd

# %%
df = pd.read_csv('D:/# 개인 폴더/2024 SKHU/2024 - 2학기/3. 데이터분석입문/Doit_Python/Data/exam.csv')

# %%
exam=df
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.query('nclass==1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query(nclass==1)   ## 에러가 나지 않도록 주의 (문자열이 쿼리임.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 exam.query(nclass==1)   ## 에러가 나지 않도록 주의 (문자열이 쿼리임.)
#
# NameError: name 'nclass' is not defined

# %% [markdown]
# ## 💡memo
# * = : 오른쪽 수식의 결과를 왼쪽 변수에 저장 -> 대입연산자<br>
# * == : "왼쪽과 오른쪽의 결과가 같다" 라는 명제를 평가  -> 비교연산자 <br>
# * != : "왼쪽과 오른쪽의 결과가 다르다" 라는 명제를 평가 -> 비교연산자

# %%
exam.query('nclass==2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('nclass!=2')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('math>=50') # query는 참인 애들만 return하는 듯.
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ## 💡memo
# * & : 그리고, and ==> 왼쪽도 참이고 오른쪽도 참이어야 참.
# * | : 또는, or ==> 왼쪽이 참이거나 오른쪽이 참이어야 참.

# %%
exam.query('nclass==1 & math>50')
# Out:
#    id  nclass  math  english  science
# 1   2       1    60       97       60

# %%
# 수학점수가 90이상이거나 영어점수가 90이상인 학생만 추출
exam.query('english>=90 | math>=90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %%
# 1,3,5반 학생들만 뽑고 싶을때
exam.query('nclass==1 | nclass==3 | nclass==5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ## 💡memo
# * in : 왼쪽의 결과가 오른쪽에 있는지 평가 -> e.g. ) for i in range()와 비슷한 원리인듯

# %%
# 여러개의 값을 참고하려고 할때 사용하는 방법 => in
exam.query('nclass in [1,3,5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
3 in [1,3,5]
# Out:
# True

# %%
# 1반과 2반의 수학 점수 평균 비교
c1 = exam.query('nclass==1') # 1반학생 추출
c2 = exam.query('nclass==2')

# %%
c1Mean= c1['math'].mean()

# %%
c2Mean=c2['math'].sum()/len(c1['math'])  # 2가지 방식을 모두 익히기

# %% [markdown]
# ### 💡 새로운 예제 시작~~ (교재에있대~)

# %%
df = pd.DataFrame({'sex' : ['F','M','F','M'],
                   'country' : ['Korea','China','Japan','USA']})

# %%
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japan
# 3   M     USA

# %%
df.query('sex=="F" & country == "Korea"') # 내부 문자열도 묶어줘야함.
# Out:
#   sex country
# 0   F   Korea

# %%
classes = [1,3,5]

exam.query('nclass in [1,3,5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass in classes') # 전형적인 에러가 나는 방법
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\qwsa7\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File c:\Users\qwsa7\AppData\Local\Programs\Python\Python311\Lib\collections\__init__.py:1006, in ChainMap.__getitem__(self, key)
#    1005         pass
# -> 1006 return self.__missing__(key)
#
# File c:\Users\qwsa7\AppData\Local\Programs\Python\Python311\Lib\collections\__init__.py:998, in ChainMap.__missing__(self, key)
#     997 def __missing__(self, key):
# --> 998     raise KeyError(key)
#
# KeyError: 'classes'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
exam.query('nclass in @classes') # 외부변수를 불러읽어들이고 싶다면, @ 를 반드시 붙여야 에러가 안남.
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
math_cut = 80
exam.query('math < @math_cut')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 19  20       5    78       83       58

# %% [markdown]
# ![prob.png](../../추가학습자료/직접%20입력%20(make%20myself)/240919/prob.png)

# %%
# 1

# %%
car = pd.read_csv('D:/# 개인 폴더/2024 SKHU/2024 - 2학기/3. 데이터분석입문/Doit_Python/Data/mpg.csv')

# %%
car.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
d4 = car.query('displ==4')

# %%
d4m=d4['hwy'].mean()

# %%
d4m
# Out:
# 19.6

# %%
d5 = car.query('displ==5')

# %%
d5m=d5['hwy'].mean()
d5m
# Out:
# 17.0

# %%
if d4m > d5m:
    print('d4m')
else:
    print('d5m')
# Out:
# d4m

# %%
# 2
c1=car.query('manufacturer=="audi"')

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam['math','english']   # 전형적인 에러가 나는 방법, 대괄호는 하나밖에 입력 못함.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\qwsa7\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('math', 'english')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ...

# %%
exam[['math','english']] # 그래서 굳이 대괄호 안에 2개의 입력을 넣고 싶다면, 대괄호로 해서 리스트처리 후 넣어야 됨.
# Out:
#     math  english
# 0     50       98
# 1     60       97
# 2     45       86
# 3     30       98
# 4     25       80
# 5     50       89
# 6     80       90
# 7     90       78
# 8     20       98
# 9     50       98
# 10    65       65
# 11    45       85
# 12    46       98
# 13    48       87
# 14    75       56
# 15    58       98
# 16    65       68
# 17    80       78
# 18    89       68
# 19    78       83

# %%
# 데이터 프레임으로 추출하는 방법 -> 인덱스, value, 칼럼 모두 나오게 출력이 됨.
exam[['math','english','nclass']]
# Out:
#     math  english  nclass
# 0     50       98       1
# 1     60       97       1
# 2     45       86       1
# 3     30       98       1
# 4     25       80       2
# 5     50       89       2
# 6     80       90       2
# 7     90       78       2
# 8     20       98       3
# 9     50       98       3
# 10    65       65       3
# 11    45       85       3
# 12    46       98       4
# 13    48       87       4
# 14    75       56       4
# 15    58       98       4
# 16    65       68       5
# 17    80       78       5
# 18    89       68       5
# 19    78       83       5

# %%
# 시리즈로 추출하는 방법 => 그래서 결과를 보면 인덱스랑 value만 존재하며, 컬럼이 존재하지 않음
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[['math']]  # 하나만 추출할거지만, 시리즈가 아닌 데이터프레임 형식으로 추출하고 싶을때는 반드시 리스트 형식으로 값을 넣을 것
# Out:
#     math
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78

# %%
exam.drop(columns='math').head()    # drop == 필요없는 칼럼을 빼버리는 방식    -> 지금은 수학을 버림
# Out:
#    id  nclass  english  science
# 0   1       1       98       50
# 1   2       1       97       60
# 2   3       1       86       78
# 3   4       1       98       58
# 4   5       2       80       65

# %%
exam.drop(columns='math','english','science').head()    # 이렇게 갯수가 여러개일때는 리스트로 안하면 에러가 남!! 주의할 것 !!

# %%
exam.drop(columns=['math','english','science']).head()
# Out:
#    id  nclass
# 0   1       1
# 1   2       1
# 2   3       1
# 3   4       1
# 4   5       2

# %%
# 수학 점수가 50점 이상인 학생의 id와 math만 추출
# 이거를 코드 한 줄로 
exam.query('math>=50')[['id','math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam.query('math>=50')[['id','math']].head()    # 이것도 가능!
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
exam.query('math >= 50')\
    [['id','math']]\
    .head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90
