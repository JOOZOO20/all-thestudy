# %%
x=[1,2,3,4,5,6]

avg = sum(x)/len(x)
print(avg)
# Out:
# 3.5

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn # 데이터 시각화 하는데 유용한 패키지

# %%
var =['a','b','c','d','a','c']

# %%
seaborn.countplot(x=var)
# Out:
# <Axes: ylabel='count'>

# %%
seaborn.countplot(y=var)
# Out:
# <Axes: xlabel='count'>

# %%
seaborn.countplot(z=var) #xy평면에 z축이 있을리가.. so, 해당 함수는 z축(3차원)을 지원하지 않음
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.countplot(x=var)
# Out:
# <Axes: ylabel='count'>

# %%
df = sns.load_dataset('titanic')     # 저 문자열에 해당하는 dataset을 불러와서 내뱉음
a= sns.load_dataset('titanic')

# %%
sns.countplot(data=df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=df, x='age')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.countplot(data=df,x='class',hue='alive')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
a=sns.countplot(data=df,x='survived',hue='alive')
# b=sns.countplot(data=df,x='survived')

# alive는 no인지 yes인지 0과 1이 무엇을 나타내는지를 직관적으로 알려주는 속성임

# %%
sns.countplot(data=df,y='class',hue='alive')
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %%
# 행은 column
# 열은 index
# 내부 값은 values

# %%
# 살앗음 1 죽엇음 0
# sibsp는 형제 잇냐고, 잇으면 1, 없으면 0 (sibling)
# 이런 정보는 seaborn 홈페이지 가보면 더 자세히 알 수 잇음

# %%
sns.countplot?
# ? 로 호출하게 되면, 해당 함수로 활용하게 되는 입력값들이 뜨게 됨
# saturation같은 값들은 0.75로 기본 세팅이 되어있는 거고, 만약 따로 지정하고 싶다면 본인이 넣으면 됨.
# Out:
# Signature:
# sns.countplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     order=None,
#     hue_order=None,
#     orient=None,
#     color=None,
#     palette=None,
#     saturation=0.75,
#     fill=True,
#     hue_norm=None,
#     stat='count',
#     width=0.8,
#     dodge='auto',
#     gap=0,
#     log_scale=None,
#     native_scale=False,
#     formatter=None,
#     legend='auto',
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Show the counts of observations in each categorical bin using bars.
#
# A count plot can be thought of as a histogram across a categorical, instead
# of quantitative, variable. The basic API and options are identical to those
# for :func:`barplot`, so you can compare counts across nested variables.
#
# Note that :func:`histplot` function offers similar functionality with additional
# features (e.g. bar stacking), although its default behavior is somewhat different.
#
# ...

# %%
# import sys
# !{sys.executable} -m pip install scikit-learn

# %%
# m1
import sklearn.metrics  #sklearn패키지 안에, metrics 모듈만 import 한다.  
sklearn.metrics.accuracy_score()

# m2 - 다만 이 방법은 코드가 길어질때, 변수명이 혼동될 수 있으니 주의할 것.
from sklearn.metrics import accuracy_score  # same meaning
accuracy_score()

#m3
from sklearn import metrics  # same meaning
metrics.accuracy_score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 3
#       1 # m1
#       2 import sklearn.metrics  #sklearn패키지 안에, metrics 모듈만 import 한다.
# ----> 3 sklearn.metrics.accuracy_score()
#       5 # m2
#       6 from sklearn.metrics import accuracy_score  # same meaning
#
# File c:\Users\qwsa7\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
# --> 191 params = func_sig.bind(*args, **kwargs)
#     192 params.apply_defaults()
#     194 # ignore self/cls and positional/keyword markers
#
# File c:\Users\qwsa7\AppData\Local\Programs\Python\Python311\Lib\inspect.py:3212, in Signature.bind(self, *args, **kwargs)
#    3207 def bind(self, /, *args, **kwargs):
# ...

# %%
sklearn.metrics.accuracy_score?
# Out:
# Signature:
# sklearn.metrics.accuracy_score(
#     y_true,
#     y_pred,
#     *,
#     normalize=True,
#     sample_weight=None,
# )
# Docstring:
# Accuracy classification score.
#
# In multilabel classification, this function computes subset accuracy:
# the set of labels predicted for a sample must *exactly* match the
# corresponding set of labels in y_true.
#
# Read more in the :ref:`User Guide <accuracy_score>`.
#
# Parameters
# ----------
# y_true : 1d array-like, or label indicator array / sparse matrix
#     Ground truth (correct) labels.
#
# y_pred : 1d array-like, or label indicator array / sparse matrix
#     Predicted labels, as returned by a classifier.
#
# normalize : bool, default=True
#     If ``False``, return the number of correctly classified samples.
#     Otherwise, return the fraction of correctly classified samples.
#
# sample_weight : array-like of shape (n_samples,), default=None
#     Sample weights.
#
# Returns
# -------
# score : float or int
# ...

# %%
# import sys
# !{sys.executable} -m pip install pydataset
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.9 MB 1.3 MB/s eta 0:00:13
#      ---------------------------------------- 0.2/15.9 MB 2.3 MB/s eta 0:00:07
#      - -------------------------------------- 0.5/15.9 MB 4.7 MB/s eta 0:00:04
#      - -------------------------------------- 0.8/15.9 MB 5.5 MB/s eta 0:00:03
#      --- ------------------------------------ 1.2/15.9 MB 7.1 MB/s eta 0:00:03
#      --- ------------------------------------ 1.6/15.9 MB 7.8 MB/s eta 0:00:02
#      ----- ---------------------------------- 2.1/15.9 MB 8.5 MB/s eta 0:00:02
#      ------ --------------------------------- 2.7/15.9 MB 9.4 MB/s eta 0:00:02
#      ------- -------------------------------- 3.1/15.9 MB 9.9 MB/s eta 0:00:02
# ...

# %%
import pydataset
pydataset.data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
pydataset.data('mtcars')
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
df = pydataset.data('mtcars')

# %%
# 오늘 자 배운것 총정리
'''
# 패키지와 모듈의 차이, 그것들의 사용법
- seaborn (as sns)
- countplot
- sklearn

'''
# Out:
# '\n# 패키지와 모듈의 차이, 그것들의 사용법\n- seaborn (as sns)\n- countplot\n- sklearn\n\n'
