# %%
#2-1
import numpy as np
import matplotlib.pyplot as plt

#(a)
x=np.linspace(-4,4,801)
y=2*x+1
plt.plot(x,y)
plt.show()


#(b)
x=np.linspace(-4,4,801)
y = -x+2
plt.plot(x,y)
plt.show()

# %%
#2-2
#(A)
x=np.linspace(-5,3,801)
y=(x+1)**2-1
plt.plot(x,y)
plt.show()

#(b)
x=np.linspace(-3,5,801)
y=-0.5*(x-1)**2+2
plt.plot(x,y)
# plt.xlabel('x')
# plt.axhline(0,color='black',lw=1)
# plt.ylabel('y')
plt.show()

# %%
# Ex 2.6
import numpy as np
import matplotlib.pyplot as plt

# (a) y1=3^x, y2=3^(x-1)+2
x = np.linspace(-1,2,301)
y1 = 3**x
y2 = 3**(x-1)+2

# For visualization
graph1, = plt.plot(x,y1)
graph2, = plt.plot(x,y2)
plt.legend(handles=(graph1,graph2), labels=(r'$y=3^x$',r'$y=3^{x-1}+2$'))
plt.show()

# (b) y1=2^(-x), y2=-2^(-x-2)}
x = np.linspace(-1,2,301)
y1 = 2**(-x)
y2 = -2**(-x-2)

# For visualization
graph1, = plt.plot(x,y1)
graph2, = plt.plot(x,y2)
plt.legend(handles=(graph1,graph2), labels=(r'$y=2^{-x}$',r'$y=-2^{-x-2}$'))
plt.show()

# %%
# Ex 2.10
import numpy as np
import matplotlib.pyplot as plt

# y1=log_2(x), y2=log_2(x+1)-1
x1 = np.linspace(0.1,4,401)
y1 = np.log2(x1)
x2 = np.linspace(-0.9,4,501)
y2 = np.log2(x2+1)-1

# For visualization
graph1, = plt.plot(x1,y1)
graph2, = plt.plot(x2,y2)
plt.legend(handles=(graph1,graph2), labels=(r'$y=log_2(x)$',r'$y=log_2(x+1)-1$'))
plt.show()

# %%
# Ex 2.11
import numpy as np

# 60(deg)
ang1deg = 60
ang1rad = np.deg2rad(ang1deg)
print("60(deg)=",ang1rad)

# -3/2pi(rad)
ang2rad = -1.5*np.pi
ang2deg = np.rad2deg(ang2rad)
print("-1.5pi(rad)=",ang2deg)
# Out:
# 60(deg)= 1.0471975511965976
# -1.5pi(rad)= -270.0

# %%
# Ex 2.14
import numpy as np
import matplotlib.pyplot as plt

# y=sin2(x+1)
x = np.linspace(-1,np.pi-1,501)
y = np.sin(2*(x+1))
plt.plot(x,y)
plt.show()

# y=-3cosx+1
x = np.linspace(0,2*np.pi,501)
y = -3*np.cos(x)+1
plt.plot(x,y)
plt.show()

# %%
# Ex 2.15
import numpy as np
import matplotlib.pyplot as plt

# y=tan2(x-pi/2)
x = np.linspace(-0.25*np.pi,0.25*np.pi,501)
y = np.tan(2*(x-0.5*np.pi))
plt.plot(x[10:491],y[10:491])
plt.show()

# %%
# Exercise 2
import matplotlib.pyplot as plt
import numpy as np

# (a) y=2*x+3
x = np.linspace(1,4,501)
fx = 2*x+3
plt.plot(x,fx)
plt.show()

# (b) y=x^2-2*x+4
x = np.linspace(-2,2,501)
gx = x**2-2*x+4
plt.plot(x,gx)
plt.show()

# %%
# Exercise 2-7
import numpy as np

# 직접 계산으로 확인하기! 4^x=7 -> x=log_4(7)
x = np.log(7)/np.log(4)  # 정리 2-8 (1)
ans = (2**x - 2**(-x)) / (2**x + 2**(-x))
print("The answer is ", ans, ".")
# Out:
# The answer is  0.75 .

# %%
# Exercise 2-9
import matplotlib.pyplot as plt
import numpy as np

# f(x)=(0.5)^(x+1)-3
def f(x):
    return (0.5)**(x+1) - 3

# Plot the graph of y=f(x)
x = np.linspace(-2, 4, 601)
fx = f(x)
plt.plot(x, fx)
plt.show()

print("Min of f : ", f(4))
print("Max of f : ", f(-2))
# Out:
# Min of f :  -2.96875
# Max of f :  -1.0

# %%
# Exercise 2-10
import matplotlib.pyplot as plt
import numpy as np

# f(x)=(log_3(x))^2-log_3(x^4)+3
def f(x):
    return (np.log(x)/np.log(3))**2 - np.log(x**4)/np.log(3) + 3

# Plot the graph of y=f(x)
x = np.linspace(0.01, 81, 1001)
fx = f(x)
plt.plot(x, fx)
plt.show()

# %%
# Ch2 Programming Practice
import numpy as np
import matplotlib.pyplot as plt

def f(x):
	return np.sin(x)

def T1(x):
	return x

def T2(x):
	return T1(x)-(1/6)*x**3

def T3(x):
	return T2(x)+(1/120)*x**5

def T4(x):
	return T3(x)-(1/5040)*x**7

# Main function
x = np.linspace(-np.pi,np.pi,1001)
y = f(x)
y1 = T1(x)
y2 = T2(x)
y3 = T3(x)
y4 = T4(x)

graph, = plt.plot(x,y)
graph1, = plt.plot(x,y1)
graph2, = plt.plot(x,y2)
graph3, = plt.plot(x,y3)
graph4, = plt.plot(x,y4)

plt.legend(handles=(graph,graph1,graph2,graph3,graph4), labels=(r'$y=sin(x)$',r'$y=T_1(x)$',r'$y=T_2(x)$',r'$y=T_3(x)$',r'$y=T_4(x)$'))
plt.show()
